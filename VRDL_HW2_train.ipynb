# %% [markdown]
# ### Training model with 10 epoch and save the model which is named as faster_rcnn1125_10_epoch

# %%
import os
import numpy as np
import torch
import torch.utils.data
from PIL import Image
import pandas as pd
import torchvision
from engine import train_one_epoch, evaluate
import utils
from model_utils import get_detection_model, get_transform
from datetime import datetime


class SVHDDataset(torch.utils.data.Dataset):
    def __init__(self, df_dir, image_dir, transforms=None):
        self.df = pd.read_csv(df_dir)
        self.image_ids = self.df['filename'].unique()
        self.image_dir = image_dir
        self.transforms = transforms

    def __getitem__(self, idx):
        image_id = self.image_ids[idx]
        records = self.df[self.df['filename'] == image_id]
        im_name = str(image_id) + ".png"
        img = Image.open(self.image_dir + im_name).convert("RGB")
        boxes = records[['x0', 'y0', 'x1', 'y1']].values
        boxes = torch.tensor(boxes, dtype=torch.int64)
        labels = records[['label']].values
        iscrowd = torch.zeros(labels.reshape(-1, ).shape, dtype=torch.int64)
        labels = torch.tensor(labels.reshape(-1, ), dtype=torch.int64)
        target = {}
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        target["area"] = area
        target['boxes'] = boxes
        target['labels'] = labels
        target['image_id'] = torch.tensor([idx])
        target['iscrowd'] = iscrowd
        if self.transforms is not None:
            img, target = self.transforms(img, target)
        return img, target

    def __len__(self):
        return self.image_ids.shape[0]

# %%
train_dir = "/Main/train/"
train_annotations = "/Main/train_ann.csv"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = 11  # 10 class (digits) + background

# use defined dataset to get data
dataset = SVHDDataset(train_annotations, train_dir, get_transform(train=True))
dataset_test = SVHDDataset(train_annotations, train_dir,
                           get_transform(train=False))
# split the dataset in train and test set
torch.manual_seed(1)
indices = torch.randperm(len(dataset)).tolist()
dataset = torch.utils.data.Subset(dataset, indices[:int(len(indices) * 0.9)])
dataset_test = torch.utils.data.Subset(dataset_test,
                                       indices[int(len(indices) * 0.9):])
# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(dataset,
                                          batch_size=4,
                                          shuffle=True,
                                          collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(dataset_test,
                                               batch_size=4,
                                               shuffle=False,
                                               collate_fn=utils.collate_fn)

model = get_detection_model(num_classes)
model.to(device)
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params,
                            lr=0.005,
                            momentum=0.9,
                            weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
num_epochs = 10

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model,
                    optimizer,
                    data_loader,
                    device,
                    epoch,
                    print_freq=1000)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1634272178570/work/aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Epoch: [0]  [   0/7516]  eta: 1:23:04  lr: 0.000010  loss: 2.9382 (2.9382)  loss_classifier: 2.6293 (2.6293)  loss_box_reg: 0.2195 (0.2195)  loss_objectness: 0.0784 (0.0784)  loss_rpn_box_reg: 0.0110 (0.0110)  time: 0.6632  data: 0.0082  max mem: 3939
# Epoch: [0]  [1000/7516]  eta: 1:33:44  lr: 0.005000  loss: 0.2922 (0.4704)  loss_classifier: 0.1272 (0.2477)  loss_box_reg: 0.1430 (0.2062)  loss_objectness: 0.0028 (0.0084)  loss_rpn_box_reg: 0.0059 (0.0080)  time: 0.9160  data: 0.0056  max mem: 5318
# Epoch: [0]  [2000/7516]  eta: 1:22:21  lr: 0.005000  loss: 0.3203 (0.3867)  loss_classifier: 0.1351 (0.1876)  loss_box_reg: 0.1644 (0.1851)  loss_objectness: 0.0027 (0.0066)  loss_rpn_box_reg: 0.0059 (0.0075)  time: 0.9138  data: 0.0056  max mem: 5318
# Epoch: [0]  [3000/7516]  eta: 1:08:07  lr: 0.005000  loss: 0.2826 (0.3516)  loss_classifier: 0.1081 (0.1620)  loss_box_reg: 0.1649 (0.1763)  loss_objectness: 0.0017 (0.0061)  loss_rpn_box_reg: 0.0057 (0.0072)  time: 0.9361  data: 0.0054  max mem: 5318
# Epoch: [0]  [4000/7516]  eta: 0:53:23  lr: 0.005000  loss: 0.2551 (0.3310)  loss_classifier: 0.0874 (0.1476)  loss_box_reg: 0.1402 (0.1706)  loss_objectness: 0.0017 (0.0057)  loss_rpn_box_reg: 0.0041 (0.0070)  time: 0.9238  data: 0.0057  max mem: 5322
# Epoch: [0]  [5000/7516]  eta: 0:38:19  lr: 0.005000  loss: 0.2177 (0.3172)  loss_classifier: 0.0807 (0.1380)  loss_box_reg: 0.1343 (0.1670)  loss_objectness: 0.0010 (0.0053)  loss_rpn_box_reg: 0.0044 (0.0069)  time: 0.9146  data: 0.0057  max mem: 5685
# Epoch: [0]  [6000/7516]  eta: 0:23:09  lr: 0.005000  loss: 0.2448 (0.3063)  loss_classifier: 0.0734 (0.1306)  loss_box_reg: 0.1554 (0.1639)  loss_objectness: 0.0019 (0.0050)  loss_rpn_box_reg: 0.0069 (0.0067)  time: 0.9211  data: 0.0058  max mem: 5685
# Epoch: [0]  [7000/7516]  eta: 0:07:53  lr: 0.005000  loss: 0.2493 (0.2991)  loss_classifier: 0.0779 (0.1258)  loss_box_reg: 0.1608 (0.1618)  loss_objectness: 0.0019 (0.0048)  loss_rpn_box_reg: 0.0063 (0.0067)  time: 0.9186  data: 0.0056  max mem: 5685
# Epoch: [0]  [7515/7516]  eta: 0:00:00  lr: 0.005000  loss: 0.2104 (0.2956)  loss_classifier: 0.0826 (0.1235)  loss_box_reg: 0.1255 (0.1608)  loss_objectness: 0.0018 (0.0047)  loss_rpn_box_reg: 0.0050 (0.0066)  time: 0.8894  data: 0.0056  max mem: 5685
# Epoch: [0] Total time: 1:54:58 (0.9179 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:13  model_time: 0.1973 (0.1973)  evaluator_time: 0.0080 (0.0080)  time: 0.2313  data: 0.0076  max mem: 5685
# Test:  [100/836]  eta: 0:03:17  model_time: 0.3323 (0.2542)  evaluator_time: 0.0076 (0.0076)  time: 0.3468  data: 0.0052  max mem: 5685
# Test:  [200/836]  eta: 0:03:19  model_time: 0.3465 (0.2991)  evaluator_time: 0.0078 (0.0077)  time: 0.3659  data: 0.0053  max mem: 5685
# Test:  [300/836]  eta: 0:02:57  model_time: 0.3630 (0.3177)  evaluator_time: 0.0074 (0.0077)  time: 0.3760  data: 0.0052  max mem: 5685
# Test:  [400/836]  eta: 0:02:29  model_time: 0.3650 (0.3281)  evaluator_time: 0.0075 (0.0077)  time: 0.3750  data: 0.0056  max mem: 5685
# Test:  [500/836]  eta: 0:01:57  model_time: 0.3595 (0.3344)  evaluator_time: 0.0077 (0.0077)  time: 0.3701  data: 0.0051  max mem: 5685
# Test:  [600/836]  eta: 0:01:23  model_time: 0.3614 (0.3391)  evaluator_time: 0.0076 (0.0077)  time: 0.3743  data: 0.0057  max mem: 5685
# Test:  [700/836]  eta: 0:00:48  model_time: 0.3703 (0.3430)  evaluator_time: 0.0074 (0.0078)  time: 0.3808  data: 0.0057  max mem: 5685
# Test:  [800/836]  eta: 0:00:12  model_time: 0.3594 (0.3461)  evaluator_time: 0.0073 (0.0078)  time: 0.3719  data: 0.0050  max mem: 5685
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3557 (0.3465)  evaluator_time: 0.0076 (0.0078)  time: 0.3589  data: 0.0051  max mem: 5685
# Test: Total time: 0:05:01 (0.3604 s / it)
# Averaged stats: model_time: 0.3557 (0.3465)  evaluator_time: 0.0076 (0.0078)
# Accumulating evaluation results...
# DONE (t=0.85s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.429
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.881
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.341
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.416
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.482
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.574
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.493
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.530
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.579
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.615
# Epoch: [1]  [   0/7516]  eta: 1:10:11  lr: 0.005000  loss: 0.2643 (0.2643)  loss_classifier: 0.0980 (0.0980)  loss_box_reg: 0.1515 (0.1515)  loss_objectness: 0.0030 (0.0030)  loss_rpn_box_reg: 0.0118 (0.0118)  time: 0.5604  data: 0.0057  max mem: 5685
# Epoch: [1]  [1000/7516]  eta: 1:39:06  lr: 0.005000  loss: 0.2206 (0.2473)  loss_classifier: 0.0723 (0.0911)  loss_box_reg: 0.1256 (0.1460)  loss_objectness: 0.0018 (0.0038)  loss_rpn_box_reg: 0.0051 (0.0063)  time: 0.9077  data: 0.0057  max mem: 5685
# Epoch: [1]  [2000/7516]  eta: 1:24:01  lr: 0.005000  loss: 0.2125 (0.2460)  loss_classifier: 0.0857 (0.0900)  loss_box_reg: 0.1267 (0.1464)  loss_objectness: 0.0025 (0.0035)  loss_rpn_box_reg: 0.0050 (0.0061)  time: 0.9045  data: 0.0057  max mem: 5685
# Epoch: [1]  [3000/7516]  eta: 1:08:52  lr: 0.005000  loss: 0.2168 (0.2462)  loss_classifier: 0.0667 (0.0902)  loss_box_reg: 0.1404 (0.1467)  loss_objectness: 0.0023 (0.0033)  loss_rpn_box_reg: 0.0055 (0.0060)  time: 0.9169  data: 0.0059  max mem: 5685
# Epoch: [1]  [4000/7516]  eta: 0:53:34  lr: 0.005000  loss: 0.2705 (0.2452)  loss_classifier: 0.0897 (0.0898)  loss_box_reg: 0.1622 (0.1461)  loss_objectness: 0.0009 (0.0032)  loss_rpn_box_reg: 0.0056 (0.0060)  time: 0.8914  data: 0.0061  max mem: 5685
# Epoch: [1]  [5000/7516]  eta: 0:38:20  lr: 0.005000  loss: 0.2133 (0.2451)  loss_classifier: 0.0819 (0.0898)  loss_box_reg: 0.1210 (0.1459)  loss_objectness: 0.0020 (0.0034)  loss_rpn_box_reg: 0.0048 (0.0060)  time: 0.9238  data: 0.0059  max mem: 5685
# Epoch: [1]  [6000/7516]  eta: 0:23:06  lr: 0.005000  loss: 0.2313 (0.2453)  loss_classifier: 0.0837 (0.0899)  loss_box_reg: 0.1432 (0.1461)  loss_objectness: 0.0020 (0.0033)  loss_rpn_box_reg: 0.0053 (0.0060)  time: 0.9229  data: 0.0059  max mem: 5685
# Epoch: [1]  [7000/7516]  eta: 0:07:52  lr: 0.005000  loss: 0.2435 (0.2446)  loss_classifier: 0.0699 (0.0895)  loss_box_reg: 0.1220 (0.1457)  loss_objectness: 0.0013 (0.0034)  loss_rpn_box_reg: 0.0045 (0.0060)  time: 0.8907  data: 0.0057  max mem: 5685
# Epoch: [1]  [7515/7516]  eta: 0:00:00  lr: 0.005000  loss: 0.2214 (0.2446)  loss_classifier: 0.0676 (0.0895)  loss_box_reg: 0.1489 (0.1457)  loss_objectness: 0.0014 (0.0034)  loss_rpn_box_reg: 0.0061 (0.0061)  time: 0.8773  data: 0.0054  max mem: 5685
# Epoch: [1] Total time: 1:54:33 (0.9146 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:14  model_time: 0.1993 (0.1993)  evaluator_time: 0.0071 (0.0071)  time: 0.2328  data: 0.0078  max mem: 5685
# Test:  [100/836]  eta: 0:03:16  model_time: 0.3358 (0.2538)  evaluator_time: 0.0072 (0.0073)  time: 0.3478  data: 0.0052  max mem: 5685
# Test:  [200/836]  eta: 0:03:18  model_time: 0.3426 (0.2984)  evaluator_time: 0.0074 (0.0073)  time: 0.3594  data: 0.0054  max mem: 5685
# Test:  [300/836]  eta: 0:02:56  model_time: 0.3622 (0.3169)  evaluator_time: 0.0070 (0.0073)  time: 0.3783  data: 0.0051  max mem: 5685
# Test:  [400/836]  eta: 0:02:28  model_time: 0.3573 (0.3270)  evaluator_time: 0.0071 (0.0073)  time: 0.3765  data: 0.0056  max mem: 5685
# Test:  [500/836]  eta: 0:01:56  model_time: 0.3387 (0.3333)  evaluator_time: 0.0072 (0.0073)  time: 0.3666  data: 0.0052  max mem: 5685
# Test:  [600/836]  eta: 0:01:22  model_time: 0.3577 (0.3378)  evaluator_time: 0.0071 (0.0075)  time: 0.3719  data: 0.0055  max mem: 5685
# Test:  [700/836]  eta: 0:00:48  model_time: 0.3567 (0.3414)  evaluator_time: 0.0071 (0.0075)  time: 0.3760  data: 0.0057  max mem: 5685
# Test:  [800/836]  eta: 0:00:12  model_time: 0.3593 (0.3443)  evaluator_time: 0.0070 (0.0074)  time: 0.3719  data: 0.0051  max mem: 5685
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3542 (0.3445)  evaluator_time: 0.0069 (0.0074)  time: 0.3536  data: 0.0051  max mem: 5685
# Test: Total time: 0:04:59 (0.3579 s / it)
# Averaged stats: model_time: 0.3542 (0.3445)  evaluator_time: 0.0069 (0.0074)
# Accumulating evaluation results...
# DONE (t=0.68s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.882
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.342
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.416
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.467
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.589
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.491
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.535
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.535
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.532
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.608
# Epoch: [2]  [   0/7516]  eta: 1:26:58  lr: 0.005000  loss: 0.3650 (0.3650)  loss_classifier: 0.2133 (0.2133)  loss_box_reg: 0.1463 (0.1463)  loss_objectness: 0.0025 (0.0025)  loss_rpn_box_reg: 0.0030 (0.0030)  time: 0.6944  data: 0.0102  max mem: 5685
# Epoch: [2]  [1000/7516]  eta: 1:38:31  lr: 0.005000  loss: 0.2442 (0.2441)  loss_classifier: 0.0857 (0.0886)  loss_box_reg: 0.1469 (0.1460)  loss_objectness: 0.0023 (0.0034)  loss_rpn_box_reg: 0.0057 (0.0061)  time: 0.9112  data: 0.0060  max mem: 5685
# Epoch: [2]  [2000/7516]  eta: 1:23:14  lr: 0.005000  loss: 0.2046 (0.2431)  loss_classifier: 0.0721 (0.0879)  loss_box_reg: 0.1314 (0.1456)  loss_objectness: 0.0013 (0.0035)  loss_rpn_box_reg: 0.0049 (0.0062)  time: 0.8894  data: 0.0058  max mem: 5685
# Epoch: [2]  [3000/7516]  eta: 1:08:09  lr: 0.005000  loss: 0.2242 (0.2422)  loss_classifier: 0.0684 (0.0875)  loss_box_reg: 0.1430 (0.1452)  loss_objectness: 0.0012 (0.0034)  loss_rpn_box_reg: 0.0054 (0.0061)  time: 0.8972  data: 0.0057  max mem: 5685
# Epoch: [2]  [4000/7516]  eta: 0:53:01  lr: 0.005000  loss: 0.2329 (0.2425)  loss_classifier: 0.0719 (0.0877)  loss_box_reg: 0.1323 (0.1453)  loss_objectness: 0.0044 (0.0034)  loss_rpn_box_reg: 0.0050 (0.0061)  time: 0.8854  data: 0.0066  max mem: 5685
# Epoch: [2]  [5000/7516]  eta: 0:37:55  lr: 0.005000  loss: 0.2190 (0.2420)  loss_classifier: 0.0683 (0.0878)  loss_box_reg: 0.1365 (0.1449)  loss_objectness: 0.0009 (0.0033)  loss_rpn_box_reg: 0.0044 (0.0060)  time: 0.9107  data: 0.0055  max mem: 5685
# Epoch: [2]  [6000/7516]  eta: 0:22:50  lr: 0.005000  loss: 0.2014 (0.2405)  loss_classifier: 0.0683 (0.0872)  loss_box_reg: 0.1292 (0.1441)  loss_objectness: 0.0020 (0.0032)  loss_rpn_box_reg: 0.0048 (0.0060)  time: 0.9043  data: 0.0057  max mem: 5685
# Epoch: [2]  [7000/7516]  eta: 0:07:46  lr: 0.005000  loss: 0.2329 (0.2398)  loss_classifier: 0.0749 (0.0868)  loss_box_reg: 0.1329 (0.1437)  loss_objectness: 0.0021 (0.0032)  loss_rpn_box_reg: 0.0052 (0.0060)  time: 0.8975  data: 0.0058  max mem: 5685
# Epoch: [2]  [7515/7516]  eta: 0:00:00  lr: 0.005000  loss: 0.2283 (0.2403)  loss_classifier: 0.0889 (0.0869)  loss_box_reg: 0.1392 (0.1440)  loss_objectness: 0.0020 (0.0033)  loss_rpn_box_reg: 0.0049 (0.0060)  time: 0.8613  data: 0.0055  max mem: 5685
# Epoch: [2] Total time: 1:53:02 (0.9025 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:05  model_time: 0.1897 (0.1897)  evaluator_time: 0.0080 (0.0080)  time: 0.2223  data: 0.0072  max mem: 5685
# Test:  [100/836]  eta: 0:03:12  model_time: 0.3276 (0.2474)  evaluator_time: 0.0073 (0.0074)  time: 0.3395  data: 0.0053  max mem: 5685
# Test:  [200/836]  eta: 0:03:15  model_time: 0.3370 (0.2932)  evaluator_time: 0.0075 (0.0075)  time: 0.3550  data: 0.0054  max mem: 5685
# Test:  [300/836]  eta: 0:02:54  model_time: 0.3509 (0.3117)  evaluator_time: 0.0071 (0.0075)  time: 0.3722  data: 0.0098  max mem: 5685
# Test:  [400/836]  eta: 0:02:26  model_time: 0.3512 (0.3219)  evaluator_time: 0.0073 (0.0074)  time: 0.3698  data: 0.0057  max mem: 5685
# Test:  [500/836]  eta: 0:01:54  model_time: 0.3313 (0.3282)  evaluator_time: 0.0073 (0.0074)  time: 0.3606  data: 0.0050  max mem: 5685
# Test:  [600/836]  eta: 0:01:21  model_time: 0.3464 (0.3330)  evaluator_time: 0.0071 (0.0074)  time: 0.3666  data: 0.0057  max mem: 5685
# Test:  [700/836]  eta: 0:00:47  model_time: 0.3529 (0.3366)  evaluator_time: 0.0073 (0.0074)  time: 0.3691  data: 0.0056  max mem: 5685
# Test:  [800/836]  eta: 0:00:12  model_time: 0.3553 (0.3395)  evaluator_time: 0.0073 (0.0074)  time: 0.3662  data: 0.0051  max mem: 5685
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3463 (0.3398)  evaluator_time: 0.0071 (0.0074)  time: 0.3506  data: 0.0052  max mem: 5685
# Test: Total time: 0:04:55 (0.3533 s / it)
# Averaged stats: model_time: 0.3463 (0.3398)  evaluator_time: 0.0071 (0.0074)
# Accumulating evaluation results...
# DONE (t=0.83s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.443
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.902
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.357
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.433
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.481
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.603
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.502
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.542
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.625
# Epoch: [3]  [   0/7516]  eta: 1:19:59  lr: 0.000500  loss: 0.1665 (0.1665)  loss_classifier: 0.0619 (0.0619)  loss_box_reg: 0.0969 (0.0969)  loss_objectness: 0.0054 (0.0054)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 0.6386  data: 0.0063  max mem: 5685
# Epoch: [3]  [1000/7516]  eta: 1:37:13  lr: 0.000500  loss: 0.2273 (0.2278)  loss_classifier: 0.0701 (0.0777)  loss_box_reg: 0.1461 (0.1415)  loss_objectness: 0.0015 (0.0029)  loss_rpn_box_reg: 0.0042 (0.0056)  time: 0.8932  data: 0.0056  max mem: 5685
# Epoch: [3]  [2000/7516]  eta: 1:22:26  lr: 0.000500  loss: 0.2361 (0.2243)  loss_classifier: 0.0721 (0.0759)  loss_box_reg: 0.1488 (0.1403)  loss_objectness: 0.0009 (0.0027)  loss_rpn_box_reg: 0.0044 (0.0054)  time: 0.9016  data: 0.0057  max mem: 5685
# Epoch: [3]  [3000/7516]  eta: 1:07:35  lr: 0.000500  loss: 0.2094 (0.2249)  loss_classifier: 0.0677 (0.0760)  loss_box_reg: 0.1380 (0.1407)  loss_objectness: 0.0008 (0.0028)  loss_rpn_box_reg: 0.0051 (0.0054)  time: 0.9112  data: 0.0060  max mem: 5685
# Epoch: [3]  [4000/7516]  eta: 0:52:37  lr: 0.000500  loss: 0.2017 (0.2254)  loss_classifier: 0.0725 (0.0761)  loss_box_reg: 0.1204 (0.1412)  loss_objectness: 0.0012 (0.0027)  loss_rpn_box_reg: 0.0046 (0.0055)  time: 0.9182  data: 0.0055  max mem: 5685
# Epoch: [3]  [5000/7516]  eta: 0:37:40  lr: 0.000500  loss: 0.2144 (0.2246)  loss_classifier: 0.0663 (0.0758)  loss_box_reg: 0.1320 (0.1408)  loss_objectness: 0.0010 (0.0026)  loss_rpn_box_reg: 0.0048 (0.0054)  time: 0.9082  data: 0.0057  max mem: 5685
# Epoch: [3]  [6000/7516]  eta: 0:22:42  lr: 0.000500  loss: 0.2408 (0.2245)  loss_classifier: 0.0733 (0.0756)  loss_box_reg: 0.1448 (0.1408)  loss_objectness: 0.0019 (0.0026)  loss_rpn_box_reg: 0.0046 (0.0054)  time: 0.8938  data: 0.0054  max mem: 5685
# Epoch: [3]  [7000/7516]  eta: 0:07:43  lr: 0.000500  loss: 0.1955 (0.2239)  loss_classifier: 0.0655 (0.0752)  loss_box_reg: 0.1285 (0.1406)  loss_objectness: 0.0007 (0.0026)  loss_rpn_box_reg: 0.0043 (0.0054)  time: 0.9113  data: 0.0056  max mem: 5685
# Epoch: [3]  [7515/7516]  eta: 0:00:00  lr: 0.000500  loss: 0.1953 (0.2238)  loss_classifier: 0.0672 (0.0752)  loss_box_reg: 0.1203 (0.1406)  loss_objectness: 0.0011 (0.0026)  loss_rpn_box_reg: 0.0035 (0.0053)  time: 0.8681  data: 0.0054  max mem: 5685
# Epoch: [3] Total time: 1:52:34 (0.8987 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:15  model_time: 0.2026 (0.2026)  evaluator_time: 0.0069 (0.0069)  time: 0.2336  data: 0.0078  max mem: 5685
# Test:  [100/836]  eta: 0:03:12  model_time: 0.3278 (0.2476)  evaluator_time: 0.0073 (0.0080)  time: 0.3377  data: 0.0051  max mem: 5685
# Test:  [200/836]  eta: 0:03:15  model_time: 0.3401 (0.2932)  evaluator_time: 0.0074 (0.0076)  time: 0.3555  data: 0.0053  max mem: 5685
# Test:  [300/836]  eta: 0:02:54  model_time: 0.3583 (0.3118)  evaluator_time: 0.0069 (0.0075)  time: 0.3719  data: 0.0051  max mem: 5685
# Test:  [400/836]  eta: 0:02:26  model_time: 0.3642 (0.3221)  evaluator_time: 0.0070 (0.0074)  time: 0.3693  data: 0.0056  max mem: 5685
# Test:  [500/836]  eta: 0:01:54  model_time: 0.3350 (0.3282)  evaluator_time: 0.0071 (0.0074)  time: 0.3622  data: 0.0051  max mem: 5685
# Test:  [600/836]  eta: 0:01:21  model_time: 0.3553 (0.3329)  evaluator_time: 0.0070 (0.0073)  time: 0.3678  data: 0.0057  max mem: 5685
# Test:  [700/836]  eta: 0:00:47  model_time: 0.3577 (0.3364)  evaluator_time: 0.0070 (0.0074)  time: 0.3724  data: 0.0057  max mem: 5685
# Test:  [800/836]  eta: 0:00:12  model_time: 0.3544 (0.3392)  evaluator_time: 0.0069 (0.0074)  time: 0.3631  data: 0.0052  max mem: 5685
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3522 (0.3395)  evaluator_time: 0.0068 (0.0074)  time: 0.3505  data: 0.0053  max mem: 5685
# Test: Total time: 0:04:54 (0.3529 s / it)
# Averaged stats: model_time: 0.3522 (0.3395)  evaluator_time: 0.0068 (0.0074)
# Accumulating evaluation results...
# DONE (t=0.61s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.473
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.924
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.419
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.463
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.513
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.625
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.640
# Epoch: [4]  [   0/7516]  eta: 1:33:08  lr: 0.000500  loss: 0.2447 (0.2447)  loss_classifier: 0.0787 (0.0787)  loss_box_reg: 0.1609 (0.1609)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0050 (0.0050)  time: 0.7435  data: 0.0071  max mem: 5685
# Epoch: [4]  [1000/7516]  eta: 1:37:07  lr: 0.000500  loss: 0.2298 (0.2215)  loss_classifier: 0.0682 (0.0724)  loss_box_reg: 0.1405 (0.1404)  loss_objectness: 0.0012 (0.0031)  loss_rpn_box_reg: 0.0048 (0.0055)  time: 0.8888  data: 0.0060  max mem: 5685
# Epoch: [4]  [2000/7516]  eta: 1:22:24  lr: 0.000500  loss: 0.2444 (0.2208)  loss_classifier: 0.0700 (0.0726)  loss_box_reg: 0.1550 (0.1403)  loss_objectness: 0.0014 (0.0028)  loss_rpn_box_reg: 0.0054 (0.0052)  time: 0.8824  data: 0.0055  max mem: 5685
# Epoch: [4]  [3000/7516]  eta: 1:07:28  lr: 0.000500  loss: 0.1984 (0.2217)  loss_classifier: 0.0642 (0.0736)  loss_box_reg: 0.1272 (0.1402)  loss_objectness: 0.0010 (0.0027)  loss_rpn_box_reg: 0.0052 (0.0053)  time: 0.8875  data: 0.0056  max mem: 5685
# Epoch: [4]  [4000/7516]  eta: 0:52:33  lr: 0.000500  loss: 0.1911 (0.2220)  loss_classifier: 0.0573 (0.0739)  loss_box_reg: 0.1293 (0.1403)  loss_objectness: 0.0013 (0.0026)  loss_rpn_box_reg: 0.0043 (0.0053)  time: 0.9100  data: 0.0057  max mem: 5685
# Epoch: [4]  [5000/7516]  eta: 0:37:36  lr: 0.000500  loss: 0.2382 (0.2221)  loss_classifier: 0.0785 (0.0739)  loss_box_reg: 0.1425 (0.1403)  loss_objectness: 0.0011 (0.0026)  loss_rpn_box_reg: 0.0046 (0.0053)  time: 0.9119  data: 0.0059  max mem: 5685
# Epoch: [4]  [6000/7516]  eta: 0:22:39  lr: 0.000500  loss: 0.2076 (0.2217)  loss_classifier: 0.0630 (0.0739)  loss_box_reg: 0.1353 (0.1400)  loss_objectness: 0.0011 (0.0025)  loss_rpn_box_reg: 0.0047 (0.0053)  time: 0.9002  data: 0.0060  max mem: 5685
# Epoch: [4]  [7000/7516]  eta: 0:07:42  lr: 0.000500  loss: 0.1799 (0.2214)  loss_classifier: 0.0553 (0.0737)  loss_box_reg: 0.1117 (0.1398)  loss_objectness: 0.0011 (0.0026)  loss_rpn_box_reg: 0.0039 (0.0053)  time: 0.9083  data: 0.0057  max mem: 5685
# Epoch: [4]  [7515/7516]  eta: 0:00:00  lr: 0.000500  loss: 0.1872 (0.2214)  loss_classifier: 0.0653 (0.0737)  loss_box_reg: 0.1175 (0.1398)  loss_objectness: 0.0012 (0.0025)  loss_rpn_box_reg: 0.0034 (0.0053)  time: 0.8464  data: 0.0058  max mem: 5685
# Epoch: [4] Total time: 1:52:19 (0.8967 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:06  model_time: 0.1905 (0.1905)  evaluator_time: 0.0076 (0.0076)  time: 0.2225  data: 0.0072  max mem: 5685
# Test:  [100/836]  eta: 0:03:11  model_time: 0.3245 (0.2465)  evaluator_time: 0.0072 (0.0071)  time: 0.3374  data: 0.0052  max mem: 5685
# Test:  [200/836]  eta: 0:03:14  model_time: 0.3407 (0.2925)  evaluator_time: 0.0074 (0.0072)  time: 0.3540  data: 0.0053  max mem: 5685
# Test:  [300/836]  eta: 0:02:53  model_time: 0.3471 (0.3110)  evaluator_time: 0.0069 (0.0072)  time: 0.3724  data: 0.0053  max mem: 5685
# Test:  [400/836]  eta: 0:02:25  model_time: 0.3518 (0.3212)  evaluator_time: 0.0070 (0.0071)  time: 0.3678  data: 0.0057  max mem: 5685
# Test:  [500/836]  eta: 0:01:54  model_time: 0.3370 (0.3276)  evaluator_time: 0.0071 (0.0071)  time: 0.3629  data: 0.0050  max mem: 5685
# Test:  [600/836]  eta: 0:01:21  model_time: 0.3486 (0.3324)  evaluator_time: 0.0070 (0.0071)  time: 0.3683  data: 0.0055  max mem: 5685
# Test:  [700/836]  eta: 0:00:47  model_time: 0.3625 (0.3361)  evaluator_time: 0.0069 (0.0071)  time: 0.3714  data: 0.0057  max mem: 5685
# Test:  [800/836]  eta: 0:00:12  model_time: 0.3497 (0.3389)  evaluator_time: 0.0068 (0.0071)  time: 0.3630  data: 0.0051  max mem: 5685
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3470 (0.3392)  evaluator_time: 0.0067 (0.0071)  time: 0.3521  data: 0.0052  max mem: 5685
# Test: Total time: 0:04:54 (0.3524 s / it)
# Averaged stats: model_time: 0.3470 (0.3392)  evaluator_time: 0.0067 (0.0071)
# Accumulating evaluation results...
# DONE (t=0.59s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.472
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.417
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.462
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.512
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.638
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.587
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.660
# Epoch: [5]  [   0/7516]  eta: 1:21:37  lr: 0.000500  loss: 0.2600 (0.2600)  loss_classifier: 0.0730 (0.0730)  loss_box_reg: 0.1819 (0.1819)  loss_objectness: 0.0007 (0.0007)  loss_rpn_box_reg: 0.0044 (0.0044)  time: 0.6516  data: 0.0085  max mem: 5685
# Epoch: [5]  [1000/7516]  eta: 1:36:53  lr: 0.000500  loss: 0.1648 (0.2191)  loss_classifier: 0.0534 (0.0716)  loss_box_reg: 0.1034 (0.1402)  loss_objectness: 0.0005 (0.0022)  loss_rpn_box_reg: 0.0032 (0.0051)  time: 0.8752  data: 0.0057  max mem: 5685
# Epoch: [5]  [2000/7516]  eta: 1:21:57  lr: 0.000500  loss: 0.2022 (0.2199)  loss_classifier: 0.0571 (0.0728)  loss_box_reg: 0.1274 (0.1397)  loss_objectness: 0.0006 (0.0022)  loss_rpn_box_reg: 0.0032 (0.0051)  time: 0.8937  data: 0.0056  max mem: 5685
# Epoch: [5]  [3000/7516]  eta: 1:07:05  lr: 0.000500  loss: 0.1770 (0.2214)  loss_classifier: 0.0613 (0.0739)  loss_box_reg: 0.1128 (0.1401)  loss_objectness: 0.0007 (0.0023)  loss_rpn_box_reg: 0.0040 (0.0052)  time: 0.8959  data: 0.0053  max mem: 5685
# Epoch: [5]  [4000/7516]  eta: 0:52:15  lr: 0.000500  loss: 0.2044 (0.2215)  loss_classifier: 0.0722 (0.0736)  loss_box_reg: 0.1264 (0.1403)  loss_objectness: 0.0012 (0.0024)  loss_rpn_box_reg: 0.0048 (0.0052)  time: 0.9080  data: 0.0054  max mem: 5685
# Epoch: [5]  [5000/7516]  eta: 0:37:24  lr: 0.000500  loss: 0.2289 (0.2218)  loss_classifier: 0.0764 (0.0737)  loss_box_reg: 0.1367 (0.1404)  loss_objectness: 0.0013 (0.0025)  loss_rpn_box_reg: 0.0048 (0.0052)  time: 0.8823  data: 0.0058  max mem: 5685
# Epoch: [5]  [6000/7516]  eta: 0:22:32  lr: 0.000500  loss: 0.2097 (0.2220)  loss_classifier: 0.0636 (0.0738)  loss_box_reg: 0.1335 (0.1405)  loss_objectness: 0.0011 (0.0025)  loss_rpn_box_reg: 0.0043 (0.0053)  time: 0.9029  data: 0.0056  max mem: 5685
# Epoch: [5]  [7000/7516]  eta: 0:07:40  lr: 0.000500  loss: 0.2399 (0.2216)  loss_classifier: 0.0749 (0.0737)  loss_box_reg: 0.1472 (0.1403)  loss_objectness: 0.0009 (0.0024)  loss_rpn_box_reg: 0.0063 (0.0052)  time: 0.8622  data: 0.0056  max mem: 5685
# Epoch: [5]  [7515/7516]  eta: 0:00:00  lr: 0.000500  loss: 0.2027 (0.2214)  loss_classifier: 0.0617 (0.0735)  loss_box_reg: 0.1260 (0.1402)  loss_objectness: 0.0010 (0.0024)  loss_rpn_box_reg: 0.0045 (0.0052)  time: 0.8640  data: 0.0057  max mem: 5685
# Epoch: [5] Total time: 1:51:42 (0.8918 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:15  model_time: 0.2022 (0.2022)  evaluator_time: 0.0077 (0.0077)  time: 0.2337  data: 0.0072  max mem: 5685
# Test:  [100/836]  eta: 0:03:13  model_time: 0.3290 (0.2489)  evaluator_time: 0.0073 (0.0072)  time: 0.3393  data: 0.0053  max mem: 5685
# Test:  [200/836]  eta: 0:03:15  model_time: 0.3451 (0.2946)  evaluator_time: 0.0073 (0.0072)  time: 0.3560  data: 0.0053  max mem: 5685
# Test:  [300/836]  eta: 0:02:54  model_time: 0.3475 (0.3128)  evaluator_time: 0.0069 (0.0072)  time: 0.3688  data: 0.0051  max mem: 5685
# Test:  [400/836]  eta: 0:02:26  model_time: 0.3526 (0.3224)  evaluator_time: 0.0070 (0.0072)  time: 0.3689  data: 0.0057  max mem: 5685
# Test:  [500/836]  eta: 0:01:54  model_time: 0.3428 (0.3284)  evaluator_time: 0.0070 (0.0072)  time: 0.3607  data: 0.0051  max mem: 5685
# Test:  [600/836]  eta: 0:01:21  model_time: 0.3502 (0.3329)  evaluator_time: 0.0069 (0.0072)  time: 0.3676  data: 0.0056  max mem: 5685
# Test:  [700/836]  eta: 0:00:47  model_time: 0.3559 (0.3365)  evaluator_time: 0.0072 (0.0072)  time: 0.3689  data: 0.0055  max mem: 5685
# Test:  [800/836]  eta: 0:00:12  model_time: 0.3523 (0.3392)  evaluator_time: 0.0069 (0.0072)  time: 0.3698  data: 0.0104  max mem: 5685
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3533 (0.3395)  evaluator_time: 0.0068 (0.0071)  time: 0.3492  data: 0.0052  max mem: 5685
# Test: Total time: 0:04:54 (0.3527 s / it)
# Averaged stats: model_time: 0.3533 (0.3395)  evaluator_time: 0.0068 (0.0071)
# Accumulating evaluation results...
# DONE (t=0.60s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.475
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.926
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.424
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.465
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.516
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.632
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.568
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.568
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.646
# Epoch: [6]  [   0/7516]  eta: 1:26:31  lr: 0.000050  loss: 0.2981 (0.2981)  loss_classifier: 0.0840 (0.0840)  loss_box_reg: 0.1878 (0.1878)  loss_objectness: 0.0135 (0.0135)  loss_rpn_box_reg: 0.0128 (0.0128)  time: 0.6907  data: 0.0071  max mem: 5685
# Epoch: [6]  [1000/7516]  eta: 1:36:34  lr: 0.000050  loss: 0.2194 (0.2186)  loss_classifier: 0.0681 (0.0716)  loss_box_reg: 0.1424 (0.1400)  loss_objectness: 0.0026 (0.0021)  loss_rpn_box_reg: 0.0070 (0.0050)  time: 0.8744  data: 0.0059  max mem: 5685
# Epoch: [6]  [2000/7516]  eta: 1:21:54  lr: 0.000050  loss: 0.1896 (0.2166)  loss_classifier: 0.0658 (0.0706)  loss_box_reg: 0.1311 (0.1387)  loss_objectness: 0.0006 (0.0023)  loss_rpn_box_reg: 0.0037 (0.0050)  time: 0.8717  data: 0.0056  max mem: 5685
# Epoch: [6]  [3000/7516]  eta: 1:07:04  lr: 0.000050  loss: 0.2341 (0.2186)  loss_classifier: 0.0720 (0.0718)  loss_box_reg: 0.1433 (0.1391)  loss_objectness: 0.0012 (0.0025)  loss_rpn_box_reg: 0.0045 (0.0051)  time: 0.8856  data: 0.0056  max mem: 5685
# Epoch: [6]  [4000/7516]  eta: 0:52:13  lr: 0.000050  loss: 0.2330 (0.2190)  loss_classifier: 0.0599 (0.0719)  loss_box_reg: 0.1387 (0.1396)  loss_objectness: 0.0018 (0.0024)  loss_rpn_box_reg: 0.0042 (0.0051)  time: 0.8854  data: 0.0058  max mem: 5685
# Epoch: [6]  [5000/7516]  eta: 0:37:21  lr: 0.000050  loss: 0.2234 (0.2192)  loss_classifier: 0.0570 (0.0719)  loss_box_reg: 0.1332 (0.1397)  loss_objectness: 0.0010 (0.0024)  loss_rpn_box_reg: 0.0037 (0.0051)  time: 0.8952  data: 0.0057  max mem: 5685
# Epoch: [6]  [6000/7516]  eta: 0:22:30  lr: 0.000050  loss: 0.2037 (0.2188)  loss_classifier: 0.0724 (0.0717)  loss_box_reg: 0.1355 (0.1396)  loss_objectness: 0.0010 (0.0023)  loss_rpn_box_reg: 0.0047 (0.0052)  time: 0.8840  data: 0.0056  max mem: 5685
# Epoch: [6]  [7000/7516]  eta: 0:07:39  lr: 0.000050  loss: 0.1874 (0.2184)  loss_classifier: 0.0519 (0.0716)  loss_box_reg: 0.1157 (0.1393)  loss_objectness: 0.0008 (0.0023)  loss_rpn_box_reg: 0.0037 (0.0051)  time: 0.8910  data: 0.0059  max mem: 5685
# Epoch: [6]  [7515/7516]  eta: 0:00:00  lr: 0.000050  loss: 0.2068 (0.2183)  loss_classifier: 0.0588 (0.0717)  loss_box_reg: 0.1381 (0.1391)  loss_objectness: 0.0014 (0.0023)  loss_rpn_box_reg: 0.0055 (0.0051)  time: 0.8453  data: 0.0053  max mem: 5685
# Epoch: [6] Total time: 1:51:32 (0.8905 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:15  model_time: 0.2020 (0.2020)  evaluator_time: 0.0068 (0.0068)  time: 0.2335  data: 0.0076  max mem: 5685
# Test:  [100/836]  eta: 0:03:09  model_time: 0.3242 (0.2447)  evaluator_time: 0.0072 (0.0071)  time: 0.3335  data: 0.0052  max mem: 5685
# Test:  [200/836]  eta: 0:03:12  model_time: 0.3341 (0.2902)  evaluator_time: 0.0072 (0.0071)  time: 0.3527  data: 0.0053  max mem: 5685
# Test:  [300/836]  eta: 0:02:52  model_time: 0.3464 (0.3089)  evaluator_time: 0.0068 (0.0071)  time: 0.3661  data: 0.0052  max mem: 5685
# Test:  [400/836]  eta: 0:02:24  model_time: 0.3546 (0.3190)  evaluator_time: 0.0069 (0.0071)  time: 0.3678  data: 0.0057  max mem: 5685
# Test:  [500/836]  eta: 0:01:53  model_time: 0.3393 (0.3252)  evaluator_time: 0.0070 (0.0071)  time: 0.3583  data: 0.0050  max mem: 5685
# Test:  [600/836]  eta: 0:01:20  model_time: 0.3438 (0.3299)  evaluator_time: 0.0068 (0.0073)  time: 0.3655  data: 0.0056  max mem: 5685
# Test:  [700/836]  eta: 0:00:47  model_time: 0.3430 (0.3333)  evaluator_time: 0.0070 (0.0072)  time: 0.3662  data: 0.0056  max mem: 5685
# Test:  [800/836]  eta: 0:00:12  model_time: 0.3448 (0.3362)  evaluator_time: 0.0069 (0.0072)  time: 0.3603  data: 0.0051  max mem: 5685
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3512 (0.3365)  evaluator_time: 0.0067 (0.0072)  time: 0.3482  data: 0.0051  max mem: 5685
# Test: Total time: 0:04:52 (0.3497 s / it)
# Averaged stats: model_time: 0.3512 (0.3365)  evaluator_time: 0.0067 (0.0072)
# Accumulating evaluation results...
# DONE (t=0.58s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.477
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.928
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.516
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.621
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.587
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.629
# Epoch: [7]  [   0/7516]  eta: 1:17:07  lr: 0.000050  loss: 0.2285 (0.2285)  loss_classifier: 0.0661 (0.0661)  loss_box_reg: 0.1553 (0.1553)  loss_objectness: 0.0013 (0.0013)  loss_rpn_box_reg: 0.0057 (0.0057)  time: 0.6157  data: 0.0060  max mem: 5685
# Epoch: [7]  [1000/7516]  eta: 1:36:11  lr: 0.000050  loss: 0.2019 (0.2180)  loss_classifier: 0.0588 (0.0713)  loss_box_reg: 0.1371 (0.1395)  loss_objectness: 0.0009 (0.0021)  loss_rpn_box_reg: 0.0048 (0.0051)  time: 0.8824  data: 0.0057  max mem: 5685
# Epoch: [7]  [2000/7516]  eta: 1:21:25  lr: 0.000050  loss: 0.1770 (0.2179)  loss_classifier: 0.0529 (0.0716)  loss_box_reg: 0.1173 (0.1391)  loss_objectness: 0.0005 (0.0021)  loss_rpn_box_reg: 0.0046 (0.0051)  time: 0.8817  data: 0.0056  max mem: 5685
# Epoch: [7]  [3000/7516]  eta: 1:06:44  lr: 0.000050  loss: 0.1740 (0.2172)  loss_classifier: 0.0539 (0.0711)  loss_box_reg: 0.1209 (0.1389)  loss_objectness: 0.0011 (0.0021)  loss_rpn_box_reg: 0.0038 (0.0051)  time: 0.8986  data: 0.0056  max mem: 5685
# Epoch: [7]  [4000/7516]  eta: 0:51:59  lr: 0.000050  loss: 0.1952 (0.2170)  loss_classifier: 0.0593 (0.0711)  loss_box_reg: 0.1317 (0.1386)  loss_objectness: 0.0011 (0.0022)  loss_rpn_box_reg: 0.0035 (0.0051)  time: 0.8818  data: 0.0059  max mem: 5685
# Epoch: [7]  [5000/7516]  eta: 0:37:12  lr: 0.000050  loss: 0.1993 (0.2165)  loss_classifier: 0.0515 (0.0708)  loss_box_reg: 0.1168 (0.1383)  loss_objectness: 0.0005 (0.0023)  loss_rpn_box_reg: 0.0037 (0.0051)  time: 0.8988  data: 0.0057  max mem: 5685
# Epoch: [7]  [6000/7516]  eta: 0:22:25  lr: 0.000050  loss: 0.1987 (0.2169)  loss_classifier: 0.0678 (0.0710)  loss_box_reg: 0.1247 (0.1385)  loss_objectness: 0.0008 (0.0023)  loss_rpn_box_reg: 0.0043 (0.0051)  time: 0.8855  data: 0.0056  max mem: 5685
# Epoch: [7]  [7000/7516]  eta: 0:07:38  lr: 0.000050  loss: 0.2058 (0.2174)  loss_classifier: 0.0695 (0.0712)  loss_box_reg: 0.1191 (0.1387)  loss_objectness: 0.0007 (0.0023)  loss_rpn_box_reg: 0.0036 (0.0051)  time: 0.8767  data: 0.0054  max mem: 5685
# Epoch: [7]  [7515/7516]  eta: 0:00:00  lr: 0.000050  loss: 0.1995 (0.2177)  loss_classifier: 0.0689 (0.0714)  loss_box_reg: 0.1215 (0.1389)  loss_objectness: 0.0006 (0.0023)  loss_rpn_box_reg: 0.0040 (0.0051)  time: 0.8717  data: 0.0058  max mem: 5685
# Epoch: [7] Total time: 1:51:10 (0.8875 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:05  model_time: 0.1890 (0.1890)  evaluator_time: 0.0077 (0.0077)  time: 0.2216  data: 0.0072  max mem: 5685
# Test:  [100/836]  eta: 0:03:08  model_time: 0.3225 (0.2433)  evaluator_time: 0.0072 (0.0072)  time: 0.3322  data: 0.0053  max mem: 5685
# Test:  [200/836]  eta: 0:03:12  model_time: 0.3404 (0.2897)  evaluator_time: 0.0074 (0.0072)  time: 0.3539  data: 0.0053  max mem: 5685
# Test:  [300/836]  eta: 0:02:52  model_time: 0.3587 (0.3083)  evaluator_time: 0.0069 (0.0072)  time: 0.3688  data: 0.0050  max mem: 5685
# Test:  [400/836]  eta: 0:02:24  model_time: 0.3501 (0.3187)  evaluator_time: 0.0069 (0.0071)  time: 0.3658  data: 0.0057  max mem: 5685
# Test:  [500/836]  eta: 0:01:53  model_time: 0.3474 (0.3252)  evaluator_time: 0.0071 (0.0073)  time: 0.3635  data: 0.0051  max mem: 5685
# Test:  [600/836]  eta: 0:01:20  model_time: 0.3585 (0.3298)  evaluator_time: 0.0068 (0.0073)  time: 0.3651  data: 0.0055  max mem: 5685
# Test:  [700/836]  eta: 0:00:47  model_time: 0.3616 (0.3334)  evaluator_time: 0.0069 (0.0073)  time: 0.3698  data: 0.0057  max mem: 5685
# Test:  [800/836]  eta: 0:00:12  model_time: 0.3462 (0.3364)  evaluator_time: 0.0069 (0.0072)  time: 0.3625  data: 0.0050  max mem: 5685
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3476 (0.3366)  evaluator_time: 0.0068 (0.0072)  time: 0.3480  data: 0.0051  max mem: 5685
# Test: Total time: 0:04:52 (0.3498 s / it)
# Averaged stats: model_time: 0.3476 (0.3366)  evaluator_time: 0.0068 (0.0072)
# Accumulating evaluation results...
# DONE (t=0.58s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.479
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.930
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.432
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.469
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.519
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.631
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.527
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.589
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.644
# Epoch: [8]  [   0/7516]  eta: 1:31:00  lr: 0.000050  loss: 0.1550 (0.1550)  loss_classifier: 0.0414 (0.0414)  loss_box_reg: 0.1111 (0.1111)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 0.7265  data: 0.0063  max mem: 5685
# Epoch: [8]  [1000/7516]  eta: 1:36:37  lr: 0.000050  loss: 0.2267 (0.2145)  loss_classifier: 0.0669 (0.0697)  loss_box_reg: 0.1421 (0.1375)  loss_objectness: 0.0017 (0.0022)  loss_rpn_box_reg: 0.0049 (0.0051)  time: 0.9145  data: 0.0056  max mem: 5685
# Epoch: [8]  [2000/7516]  eta: 1:21:46  lr: 0.000050  loss: 0.1983 (0.2176)  loss_classifier: 0.0604 (0.0710)  loss_box_reg: 0.1274 (0.1393)  loss_objectness: 0.0004 (0.0021)  loss_rpn_box_reg: 0.0036 (0.0052)  time: 0.8951  data: 0.0060  max mem: 5685
# Epoch: [8]  [3000/7516]  eta: 1:06:56  lr: 0.000050  loss: 0.1875 (0.2179)  loss_classifier: 0.0591 (0.0711)  loss_box_reg: 0.1313 (0.1395)  loss_objectness: 0.0010 (0.0022)  loss_rpn_box_reg: 0.0038 (0.0052)  time: 0.8986  data: 0.0058  max mem: 5685
# Epoch: [8]  [4000/7516]  eta: 0:52:07  lr: 0.000050  loss: 0.2268 (0.2188)  loss_classifier: 0.0731 (0.0716)  loss_box_reg: 0.1418 (0.1399)  loss_objectness: 0.0010 (0.0022)  loss_rpn_box_reg: 0.0044 (0.0051)  time: 0.8928  data: 0.0060  max mem: 5685
# Epoch: [8]  [5000/7516]  eta: 0:37:19  lr: 0.000050  loss: 0.2033 (0.2187)  loss_classifier: 0.0687 (0.0716)  loss_box_reg: 0.1354 (0.1398)  loss_objectness: 0.0014 (0.0022)  loss_rpn_box_reg: 0.0040 (0.0051)  time: 0.8745  data: 0.0055  max mem: 5685
# Epoch: [8]  [6000/7516]  eta: 0:22:28  lr: 0.000050  loss: 0.1809 (0.2184)  loss_classifier: 0.0573 (0.0716)  loss_box_reg: 0.1068 (0.1395)  loss_objectness: 0.0007 (0.0022)  loss_rpn_box_reg: 0.0043 (0.0051)  time: 0.8811  data: 0.0060  max mem: 5685
# Epoch: [8]  [7000/7516]  eta: 0:07:39  lr: 0.000050  loss: 0.2106 (0.2184)  loss_classifier: 0.0675 (0.0716)  loss_box_reg: 0.1431 (0.1394)  loss_objectness: 0.0010 (0.0022)  loss_rpn_box_reg: 0.0040 (0.0051)  time: 0.8944  data: 0.0058  max mem: 5685
# Epoch: [8]  [7515/7516]  eta: 0:00:00  lr: 0.000050  loss: 0.1867 (0.2180)  loss_classifier: 0.0530 (0.0714)  loss_box_reg: 0.1215 (0.1392)  loss_objectness: 0.0006 (0.0022)  loss_rpn_box_reg: 0.0034 (0.0051)  time: 0.8461  data: 0.0057  max mem: 5685
# Epoch: [8] Total time: 1:51:27 (0.8898 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:15  model_time: 0.2018 (0.2018)  evaluator_time: 0.0077 (0.0077)  time: 0.2337  data: 0.0072  max mem: 5685
# Test:  [100/836]  eta: 0:03:09  model_time: 0.3231 (0.2437)  evaluator_time: 0.0071 (0.0071)  time: 0.3317  data: 0.0051  max mem: 5685
# Test:  [200/836]  eta: 0:03:12  model_time: 0.3343 (0.2902)  evaluator_time: 0.0074 (0.0071)  time: 0.3545  data: 0.0053  max mem: 5685
# Test:  [300/836]  eta: 0:02:52  model_time: 0.3695 (0.3089)  evaluator_time: 0.0068 (0.0071)  time: 0.3682  data: 0.0051  max mem: 5685
# Test:  [400/836]  eta: 0:02:24  model_time: 0.3513 (0.3189)  evaluator_time: 0.0069 (0.0071)  time: 0.3664  data: 0.0056  max mem: 5685
# Test:  [500/836]  eta: 0:01:53  model_time: 0.3427 (0.3253)  evaluator_time: 0.0070 (0.0071)  time: 0.3591  data: 0.0051  max mem: 5685
# Test:  [600/836]  eta: 0:01:20  model_time: 0.3554 (0.3301)  evaluator_time: 0.0068 (0.0071)  time: 0.3654  data: 0.0056  max mem: 5685
# Test:  [700/836]  eta: 0:00:47  model_time: 0.3594 (0.3337)  evaluator_time: 0.0070 (0.0071)  time: 0.3705  data: 0.0057  max mem: 5685
# Test:  [800/836]  eta: 0:00:12  model_time: 0.3569 (0.3368)  evaluator_time: 0.0069 (0.0071)  time: 0.3651  data: 0.0050  max mem: 5685
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3485 (0.3371)  evaluator_time: 0.0067 (0.0071)  time: 0.3484  data: 0.0051  max mem: 5685
# Test: Total time: 0:04:52 (0.3501 s / it)
# Averaged stats: model_time: 0.3485 (0.3371)  evaluator_time: 0.0067 (0.0071)
# Accumulating evaluation results...
# DONE (t=0.57s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.478
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.930
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.431
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.469
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.517
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.643
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.527
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.654
# Epoch: [9]  [   0/7516]  eta: 1:16:12  lr: 0.000005  loss: 0.1547 (0.1547)  loss_classifier: 0.0438 (0.0438)  loss_box_reg: 0.1053 (0.1053)  loss_objectness: 0.0023 (0.0023)  loss_rpn_box_reg: 0.0032 (0.0032)  time: 0.6083  data: 0.0058  max mem: 5685
# Epoch: [9]  [1000/7516]  eta: 1:36:26  lr: 0.000005  loss: 0.2180 (0.2159)  loss_classifier: 0.0711 (0.0707)  loss_box_reg: 0.1401 (0.1381)  loss_objectness: 0.0014 (0.0021)  loss_rpn_box_reg: 0.0059 (0.0051)  time: 0.8909  data: 0.0059  max mem: 5685
# Epoch: [9]  [2000/7516]  eta: 1:21:40  lr: 0.000005  loss: 0.1902 (0.2158)  loss_classifier: 0.0515 (0.0703)  loss_box_reg: 0.1249 (0.1382)  loss_objectness: 0.0011 (0.0022)  loss_rpn_box_reg: 0.0037 (0.0051)  time: 0.8756  data: 0.0059  max mem: 5685
# Epoch: [9]  [3000/7516]  eta: 1:06:53  lr: 0.000005  loss: 0.1723 (0.2160)  loss_classifier: 0.0517 (0.0703)  loss_box_reg: 0.1160 (0.1385)  loss_objectness: 0.0008 (0.0021)  loss_rpn_box_reg: 0.0037 (0.0051)  time: 0.8984  data: 0.0062  max mem: 5685
# Epoch: [9]  [4000/7516]  eta: 0:52:05  lr: 0.000005  loss: 0.2031 (0.2170)  loss_classifier: 0.0614 (0.0709)  loss_box_reg: 0.1359 (0.1389)  loss_objectness: 0.0007 (0.0022)  loss_rpn_box_reg: 0.0049 (0.0051)  time: 0.8854  data: 0.0059  max mem: 5685
# Epoch: [9]  [5000/7516]  eta: 0:37:16  lr: 0.000005  loss: 0.2092 (0.2175)  loss_classifier: 0.0642 (0.0710)  loss_box_reg: 0.1381 (0.1391)  loss_objectness: 0.0011 (0.0023)  loss_rpn_box_reg: 0.0048 (0.0051)  time: 0.9066  data: 0.0057  max mem: 5685
# Epoch: [9]  [6000/7516]  eta: 0:22:28  lr: 0.000005  loss: 0.2008 (0.2177)  loss_classifier: 0.0568 (0.0712)  loss_box_reg: 0.1378 (0.1391)  loss_objectness: 0.0007 (0.0022)  loss_rpn_box_reg: 0.0038 (0.0051)  time: 0.8927  data: 0.0054  max mem: 5685
# Epoch: [9]  [7000/7516]  eta: 0:07:38  lr: 0.000005  loss: 0.2114 (0.2175)  loss_classifier: 0.0611 (0.0712)  loss_box_reg: 0.1372 (0.1390)  loss_objectness: 0.0007 (0.0022)  loss_rpn_box_reg: 0.0044 (0.0051)  time: 0.8947  data: 0.0061  max mem: 5685
# Epoch: [9]  [7515/7516]  eta: 0:00:00  lr: 0.000005  loss: 0.1940 (0.2175)  loss_classifier: 0.0733 (0.0711)  loss_box_reg: 0.1177 (0.1390)  loss_objectness: 0.0006 (0.0023)  loss_rpn_box_reg: 0.0033 (0.0051)  time: 0.8634  data: 0.0054  max mem: 5685
# Epoch: [9] Total time: 1:51:24 (0.8894 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:15  model_time: 0.2019 (0.2019)  evaluator_time: 0.0076 (0.0076)  time: 0.2342  data: 0.0072  max mem: 5685
# Test:  [100/836]  eta: 0:03:10  model_time: 0.3224 (0.2460)  evaluator_time: 0.0072 (0.0071)  time: 0.3334  data: 0.0053  max mem: 5685
# Test:  [200/836]  eta: 0:03:13  model_time: 0.3391 (0.2917)  evaluator_time: 0.0073 (0.0071)  time: 0.3551  data: 0.0052  max mem: 5685
# Test:  [300/836]  eta: 0:02:53  model_time: 0.3548 (0.3102)  evaluator_time: 0.0067 (0.0071)  time: 0.3688  data: 0.0052  max mem: 5685
# Test:  [400/836]  eta: 0:02:25  model_time: 0.3519 (0.3203)  evaluator_time: 0.0069 (0.0071)  time: 0.3676  data: 0.0056  max mem: 5685
# Test:  [500/836]  eta: 0:01:54  model_time: 0.3403 (0.3263)  evaluator_time: 0.0071 (0.0071)  time: 0.3600  data: 0.0050  max mem: 5685
# Test:  [600/836]  eta: 0:01:21  model_time: 0.3483 (0.3309)  evaluator_time: 0.0069 (0.0071)  time: 0.3638  data: 0.0056  max mem: 5685
# Test:  [700/836]  eta: 0:00:47  model_time: 0.3538 (0.3345)  evaluator_time: 0.0069 (0.0071)  time: 0.3726  data: 0.0108  max mem: 5685
# Test:  [800/836]  eta: 0:00:12  model_time: 0.3430 (0.3373)  evaluator_time: 0.0069 (0.0071)  time: 0.3615  data: 0.0051  max mem: 5685
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3480 (0.3376)  evaluator_time: 0.0067 (0.0071)  time: 0.3492  data: 0.0052  max mem: 5685
# Test: Total time: 0:04:53 (0.3508 s / it)
# Averaged stats: model_time: 0.3480 (0.3376)  evaluator_time: 0.0067 (0.0071)
# Accumulating evaluation results...
# DONE (t=0.57s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.479
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.930
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.432
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.469
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.517
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.632
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.527
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.587
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.646

# %%
torch.save(
    {
        "epoch": 10,
        "model_state_dict": model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        "lr_scheduler": lr_scheduler.state_dict()
    }, "/Main/faster_rcnn1125_10_epoch.pth")

# %% [markdown]
# ### Training model with 5 epoch and save the model which is named as faster_rcnn1124

# %%
import os
import numpy as np
import torch
import torch.utils.data
from PIL import Image
import pandas as pd
import torchvision
from engine import train_one_epoch, evaluate
import utils
from model_utils import get_detection_model, get_transform
from datetime import datetime


class SVHDDataset(torch.utils.data.Dataset):
    def __init__(self, df_dir, image_dir, transforms=None):
        self.df = pd.read_csv(df_dir)
        self.image_ids = self.df['filename'].unique()
        self.image_dir = image_dir
        self.transforms = transforms

    def __getitem__(self, idx):
        image_id = self.image_ids[idx]
        records = self.df[self.df['filename'] == image_id]
        im_name = str(image_id) + ".png"
        img = Image.open(self.image_dir + im_name).convert("RGB")
        boxes = records[['x0', 'y0', 'x1', 'y1']].values
        boxes = torch.tensor(boxes, dtype=torch.int64)
        labels = records[['label']].values
        iscrowd = torch.zeros(labels.reshape(-1, ).shape, dtype=torch.int64)
        labels = torch.tensor(labels.reshape(-1, ), dtype=torch.int64)
        target = {}
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        target["area"] = area
        target['boxes'] = boxes
        target['labels'] = labels
        target['image_id'] = torch.tensor([idx])
        target['iscrowd'] = iscrowd
        if self.transforms is not None:
            img, target = self.transforms(img, target)
        return img, target

    def __len__(self):
        return self.image_ids.shape[0]

# %%
train_dir = "/Main/train/"
train_annotations = "/Main/train_ann.csv"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = 11  # 10 class (digits) + background

# use defined dataset to get data
dataset = SVHDDataset(train_annotations, train_dir, get_transform(train=True))
dataset_test = SVHDDataset(train_annotations, train_dir,
                           get_transform(train=False))
# split the dataset in train and test set
torch.manual_seed(1)
indices = torch.randperm(len(dataset)).tolist()
dataset = torch.utils.data.Subset(dataset, indices[:int(len(indices) * 0.9)])
dataset_test = torch.utils.data.Subset(dataset_test,
                                       indices[int(len(indices) * 0.9):])
# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(dataset,
                                          batch_size=4,
                                          shuffle=True,
                                          collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(dataset_test,
                                               batch_size=4,
                                               shuffle=False,
                                               collate_fn=utils.collate_fn)

model = get_detection_model(num_classes)
model.to(device)
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params,
                            lr=0.005,
                            momentum=0.9,
                            weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
num_epochs = 5

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model,
                    optimizer,
                    data_loader,
                    device,
                    epoch,
                    print_freq=1000)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [   0/7516]  eta: 1:17:22  lr: 0.000010  loss: 2.9217 (2.9217)  loss_classifier: 2.6321 (2.6321)  loss_box_reg: 0.1889 (0.1889)  loss_objectness: 0.0885 (0.0885)  loss_rpn_box_reg: 0.0122 (0.0122)  time: 0.6177  data: 0.0069  max mem: 4258
# Epoch: [0]  [1000/7516]  eta: 1:49:27  lr: 0.005000  loss: 0.2984 (0.4713)  loss_classifier: 0.1317 (0.2481)  loss_box_reg: 0.1527 (0.2066)  loss_objectness: 0.0025 (0.0086)  loss_rpn_box_reg: 0.0056 (0.0080)  time: 0.9886  data: 0.0056  max mem: 5640
# Epoch: [0]  [2000/7516]  eta: 1:32:17  lr: 0.005000  loss: 0.3312 (0.3885)  loss_classifier: 0.1371 (0.1883)  loss_box_reg: 0.1750 (0.1860)  loss_objectness: 0.0022 (0.0067)  loss_rpn_box_reg: 0.0062 (0.0075)  time: 0.9839  data: 0.0057  max mem: 5640
# Epoch: [0]  [3000/7516]  eta: 1:15:12  lr: 0.005000  loss: 0.2724 (0.3531)  loss_classifier: 0.1051 (0.1628)  loss_box_reg: 0.1539 (0.1770)  loss_objectness: 0.0017 (0.0061)  loss_rpn_box_reg: 0.0056 (0.0072)  time: 0.9949  data: 0.0054  max mem: 5640
# Epoch: [0]  [4000/7516]  eta: 0:58:25  lr: 0.005000  loss: 0.2517 (0.3323)  loss_classifier: 0.0912 (0.1483)  loss_box_reg: 0.1442 (0.1712)  loss_objectness: 0.0012 (0.0057)  loss_rpn_box_reg: 0.0048 (0.0070)  time: 0.9875  data: 0.0057  max mem: 5642
# Epoch: [0]  [5000/7516]  eta: 0:41:41  lr: 0.005000  loss: 0.2207 (0.3178)  loss_classifier: 0.0774 (0.1384)  loss_box_reg: 0.1318 (0.1673)  loss_objectness: 0.0013 (0.0053)  loss_rpn_box_reg: 0.0047 (0.0069)  time: 0.9689  data: 0.0057  max mem: 6008
# Epoch: [0]  [6000/7516]  eta: 0:25:03  lr: 0.005000  loss: 0.2550 (0.3065)  loss_classifier: 0.0758 (0.1308)  loss_box_reg: 0.1497 (0.1640)  loss_objectness: 0.0021 (0.0050)  loss_rpn_box_reg: 0.0063 (0.0068)  time: 0.9741  data: 0.0057  max mem: 6008
# Epoch: [0]  [7000/7516]  eta: 0:08:31  lr: 0.005000  loss: 0.2414 (0.2990)  loss_classifier: 0.0686 (0.1259)  loss_box_reg: 0.1522 (0.1617)  loss_objectness: 0.0021 (0.0048)  loss_rpn_box_reg: 0.0062 (0.0067)  time: 0.9779  data: 0.0056  max mem: 6008
# Epoch: [0]  [7515/7516]  eta: 0:00:00  lr: 0.005000  loss: 0.2286 (0.2954)  loss_classifier: 0.0761 (0.1235)  loss_box_reg: 0.1298 (0.1606)  loss_objectness: 0.0014 (0.0047)  loss_rpn_box_reg: 0.0051 (0.0066)  time: 0.9424  data: 0.0055  max mem: 6008
# Epoch: [0] Total time: 2:04:00 (0.9900 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:07  model_time: 0.1908 (0.1908)  evaluator_time: 0.0083 (0.0083)  time: 0.2243  data: 0.0076  max mem: 6008
# Test:  [100/836]  eta: 0:03:30  model_time: 0.3447 (0.2720)  evaluator_time: 0.0075 (0.0077)  time: 0.3575  data: 0.0052  max mem: 6008
# Test:  [200/836]  eta: 0:03:28  model_time: 0.3554 (0.3143)  evaluator_time: 0.0079 (0.0077)  time: 0.3748  data: 0.0053  max mem: 6008
# Test:  [300/836]  eta: 0:03:05  model_time: 0.3745 (0.3321)  evaluator_time: 0.0075 (0.0078)  time: 0.3905  data: 0.0051  max mem: 6008
# Test:  [400/836]  eta: 0:02:35  model_time: 0.3808 (0.3431)  evaluator_time: 0.0074 (0.0078)  time: 0.3935  data: 0.0057  max mem: 6008
# Test:  [500/836]  eta: 0:02:02  model_time: 0.3683 (0.3499)  evaluator_time: 0.0078 (0.0078)  time: 0.3865  data: 0.0050  max mem: 6008
# Test:  [600/836]  eta: 0:01:27  model_time: 0.3745 (0.3551)  evaluator_time: 0.0076 (0.0078)  time: 0.3986  data: 0.0121  max mem: 6008
# Test:  [700/836]  eta: 0:00:50  model_time: 0.3929 (0.3596)  evaluator_time: 0.0075 (0.0078)  time: 0.4027  data: 0.0057  max mem: 6008
# Test:  [800/836]  eta: 0:00:13  model_time: 0.3771 (0.3629)  evaluator_time: 0.0074 (0.0077)  time: 0.3898  data: 0.0051  max mem: 6008
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3777 (0.3634)  evaluator_time: 0.0073 (0.0077)  time: 0.3787  data: 0.0052  max mem: 6008
# Test: Total time: 0:05:15 (0.3772 s / it)
# Averaged stats: model_time: 0.3777 (0.3634)  evaluator_time: 0.0073 (0.0077)
# Accumulating evaluation results...
# DONE (t=0.87s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.427
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.877
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.414
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.482
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.635
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.491
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.539
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.539
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.579
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.658
# Epoch: [1]  [   0/7516]  eta: 1:21:12  lr: 0.005000  loss: 0.2598 (0.2598)  loss_classifier: 0.1023 (0.1023)  loss_box_reg: 0.1450 (0.1450)  loss_objectness: 0.0012 (0.0012)  loss_rpn_box_reg: 0.0112 (0.0112)  time: 0.6482  data: 0.0057  max mem: 6008
# Epoch: [1]  [1000/7516]  eta: 1:42:51  lr: 0.005000  loss: 0.2099 (0.2460)  loss_classifier: 0.0733 (0.0901)  loss_box_reg: 0.1293 (0.1454)  loss_objectness: 0.0019 (0.0042)  loss_rpn_box_reg: 0.0052 (0.0063)  time: 0.9389  data: 0.0056  max mem: 6008
# Epoch: [1]  [2000/7516]  eta: 1:27:11  lr: 0.005000  loss: 0.2174 (0.2461)  loss_classifier: 0.0809 (0.0900)  loss_box_reg: 0.1312 (0.1464)  loss_objectness: 0.0013 (0.0036)  loss_rpn_box_reg: 0.0051 (0.0061)  time: 0.9362  data: 0.0057  max mem: 6008
# Epoch: [1]  [3000/7516]  eta: 1:11:24  lr: 0.005000  loss: 0.2181 (0.2455)  loss_classifier: 0.0683 (0.0900)  loss_box_reg: 0.1377 (0.1461)  loss_objectness: 0.0013 (0.0034)  loss_rpn_box_reg: 0.0057 (0.0060)  time: 0.9424  data: 0.0058  max mem: 6008
# Epoch: [1]  [4000/7516]  eta: 0:55:33  lr: 0.005000  loss: 0.2697 (0.2452)  loss_classifier: 0.0929 (0.0900)  loss_box_reg: 0.1553 (0.1460)  loss_objectness: 0.0014 (0.0033)  loss_rpn_box_reg: 0.0053 (0.0060)  time: 0.9236  data: 0.0060  max mem: 6008
# Epoch: [1]  [5000/7516]  eta: 0:39:44  lr: 0.005000  loss: 0.2291 (0.2450)  loss_classifier: 0.0818 (0.0897)  loss_box_reg: 0.1291 (0.1459)  loss_objectness: 0.0022 (0.0034)  loss_rpn_box_reg: 0.0051 (0.0060)  time: 0.9520  data: 0.0059  max mem: 6008
# Epoch: [1]  [6000/7516]  eta: 0:23:56  lr: 0.005000  loss: 0.2309 (0.2449)  loss_classifier: 0.0849 (0.0897)  loss_box_reg: 0.1426 (0.1458)  loss_objectness: 0.0027 (0.0033)  loss_rpn_box_reg: 0.0059 (0.0060)  time: 0.9589  data: 0.0059  max mem: 6008
# Epoch: [1]  [7000/7516]  eta: 0:08:09  lr: 0.005000  loss: 0.2304 (0.2442)  loss_classifier: 0.0809 (0.0893)  loss_box_reg: 0.1329 (0.1455)  loss_objectness: 0.0015 (0.0034)  loss_rpn_box_reg: 0.0045 (0.0060)  time: 0.9230  data: 0.0057  max mem: 6008
# Epoch: [1]  [7515/7516]  eta: 0:00:00  lr: 0.005000  loss: 0.1952 (0.2439)  loss_classifier: 0.0573 (0.0891)  loss_box_reg: 0.1352 (0.1453)  loss_objectness: 0.0024 (0.0034)  loss_rpn_box_reg: 0.0054 (0.0060)  time: 0.9059  data: 0.0053  max mem: 6008
# Epoch: [1] Total time: 1:58:43 (0.9478 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:15  model_time: 0.2023 (0.2023)  evaluator_time: 0.0066 (0.0066)  time: 0.2341  data: 0.0071  max mem: 6008
# Test:  [100/836]  eta: 0:03:27  model_time: 0.3465 (0.2685)  evaluator_time: 0.0073 (0.0073)  time: 0.3556  data: 0.0052  max mem: 6008
# Test:  [200/836]  eta: 0:03:25  model_time: 0.3633 (0.3104)  evaluator_time: 0.0076 (0.0074)  time: 0.3698  data: 0.0052  max mem: 6008
# Test:  [300/836]  eta: 0:03:02  model_time: 0.3675 (0.3279)  evaluator_time: 0.0071 (0.0074)  time: 0.3854  data: 0.0052  max mem: 6008
# Test:  [400/836]  eta: 0:02:33  model_time: 0.3691 (0.3376)  evaluator_time: 0.0071 (0.0077)  time: 0.3833  data: 0.0056  max mem: 6008
# Test:  [500/836]  eta: 0:02:00  model_time: 0.3609 (0.3441)  evaluator_time: 0.0073 (0.0076)  time: 0.3794  data: 0.0051  max mem: 6008
# Test:  [600/836]  eta: 0:01:25  model_time: 0.3783 (0.3493)  evaluator_time: 0.0073 (0.0076)  time: 0.3872  data: 0.0056  max mem: 6008
# Test:  [700/836]  eta: 0:00:49  model_time: 0.3741 (0.3533)  evaluator_time: 0.0072 (0.0076)  time: 0.3902  data: 0.0057  max mem: 6008
# Test:  [800/836]  eta: 0:00:13  model_time: 0.3726 (0.3565)  evaluator_time: 0.0071 (0.0075)  time: 0.3836  data: 0.0050  max mem: 6008
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3698 (0.3569)  evaluator_time: 0.0070 (0.0075)  time: 0.3680  data: 0.0051  max mem: 6008
# Test: Total time: 0:05:09 (0.3703 s / it)
# Averaged stats: model_time: 0.3698 (0.3569)  evaluator_time: 0.0070 (0.0075)
# Accumulating evaluation results...
# DONE (t=0.70s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.414
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.871
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.320
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.402
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.464
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.601
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.483
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.530
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.530
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.613
# Epoch: [2]  [   0/7516]  eta: 1:39:38  lr: 0.005000  loss: 0.3752 (0.3752)  loss_classifier: 0.2257 (0.2257)  loss_box_reg: 0.1455 (0.1455)  loss_objectness: 0.0011 (0.0011)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 0.7955  data: 0.0102  max mem: 6008
# Epoch: [2]  [1000/7516]  eta: 1:41:32  lr: 0.005000  loss: 0.2376 (0.2404)  loss_classifier: 0.0898 (0.0870)  loss_box_reg: 0.1444 (0.1441)  loss_objectness: 0.0021 (0.0033)  loss_rpn_box_reg: 0.0050 (0.0061)  time: 0.9377  data: 0.0059  max mem: 6008
# Epoch: [2]  [2000/7516]  eta: 1:25:53  lr: 0.005000  loss: 0.2057 (0.2402)  loss_classifier: 0.0674 (0.0866)  loss_box_reg: 0.1317 (0.1440)  loss_objectness: 0.0017 (0.0034)  loss_rpn_box_reg: 0.0050 (0.0062)  time: 0.9243  data: 0.0058  max mem: 6008
# Epoch: [2]  [3000/7516]  eta: 1:10:28  lr: 0.005000  loss: 0.2177 (0.2395)  loss_classifier: 0.0693 (0.0864)  loss_box_reg: 0.1503 (0.1438)  loss_objectness: 0.0007 (0.0033)  loss_rpn_box_reg: 0.0052 (0.0061)  time: 0.9331  data: 0.0057  max mem: 6008
# Epoch: [2]  [4000/7516]  eta: 0:54:52  lr: 0.005000  loss: 0.2297 (0.2401)  loss_classifier: 0.0742 (0.0867)  loss_box_reg: 0.1375 (0.1441)  loss_objectness: 0.0042 (0.0033)  loss_rpn_box_reg: 0.0048 (0.0061)  time: 0.9126  data: 0.0065  max mem: 6008
# Epoch: [2]  [5000/7516]  eta: 0:39:15  lr: 0.005000  loss: 0.2253 (0.2400)  loss_classifier: 0.0787 (0.0869)  loss_box_reg: 0.1352 (0.1438)  loss_objectness: 0.0012 (0.0032)  loss_rpn_box_reg: 0.0046 (0.0060)  time: 0.9422  data: 0.0055  max mem: 6008
# Epoch: [2]  [6000/7516]  eta: 0:23:39  lr: 0.005000  loss: 0.1961 (0.2389)  loss_classifier: 0.0708 (0.0865)  loss_box_reg: 0.1210 (0.1432)  loss_objectness: 0.0019 (0.0033)  loss_rpn_box_reg: 0.0044 (0.0060)  time: 0.9440  data: 0.0057  max mem: 6008
# Epoch: [2]  [7000/7516]  eta: 0:08:03  lr: 0.005000  loss: 0.2376 (0.2383)  loss_classifier: 0.0796 (0.0860)  loss_box_reg: 0.1289 (0.1430)  loss_objectness: 0.0016 (0.0032)  loss_rpn_box_reg: 0.0049 (0.0060)  time: 0.9300  data: 0.0057  max mem: 6008
# Epoch: [2]  [7515/7516]  eta: 0:00:00  lr: 0.005000  loss: 0.2367 (0.2387)  loss_classifier: 0.0725 (0.0861)  loss_box_reg: 0.1380 (0.1433)  loss_objectness: 0.0023 (0.0033)  loss_rpn_box_reg: 0.0050 (0.0060)  time: 0.8926  data: 0.0055  max mem: 6008
# Epoch: [2] Total time: 1:57:10 (0.9355 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:16  model_time: 0.2024 (0.2024)  evaluator_time: 0.0072 (0.0072)  time: 0.2351  data: 0.0072  max mem: 6008
# Test:  [100/836]  eta: 0:03:25  model_time: 0.3376 (0.2654)  evaluator_time: 0.0075 (0.0075)  time: 0.3533  data: 0.0052  max mem: 6008
# Test:  [200/836]  eta: 0:03:24  model_time: 0.3439 (0.3080)  evaluator_time: 0.0077 (0.0075)  time: 0.3676  data: 0.0052  max mem: 6008
# Test:  [300/836]  eta: 0:03:01  model_time: 0.3700 (0.3251)  evaluator_time: 0.0072 (0.0075)  time: 0.3813  data: 0.0052  max mem: 6008
# Test:  [400/836]  eta: 0:02:31  model_time: 0.3668 (0.3348)  evaluator_time: 0.0074 (0.0075)  time: 0.3810  data: 0.0057  max mem: 6008
# Test:  [500/836]  eta: 0:01:59  model_time: 0.3507 (0.3413)  evaluator_time: 0.0074 (0.0075)  time: 0.3765  data: 0.0050  max mem: 6008
# Test:  [600/836]  eta: 0:01:24  model_time: 0.3711 (0.3458)  evaluator_time: 0.0074 (0.0075)  time: 0.3811  data: 0.0055  max mem: 6008
# Test:  [700/836]  eta: 0:00:49  model_time: 0.3779 (0.3495)  evaluator_time: 0.0072 (0.0077)  time: 0.3866  data: 0.0057  max mem: 6008
# Test:  [800/836]  eta: 0:00:13  model_time: 0.3685 (0.3526)  evaluator_time: 0.0072 (0.0077)  time: 0.3783  data: 0.0051  max mem: 6008
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3646 (0.3529)  evaluator_time: 0.0072 (0.0076)  time: 0.3631  data: 0.0051  max mem: 6008
# Test: Total time: 0:05:06 (0.3665 s / it)
# Averaged stats: model_time: 0.3646 (0.3529)  evaluator_time: 0.0072 (0.0076)
# Accumulating evaluation results...
# DONE (t=0.70s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.435
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.896
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.349
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.476
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.595
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.498
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.542
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.542
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.535
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.606
# Epoch: [3]  [   0/7516]  eta: 1:27:52  lr: 0.000500  loss: 0.1673 (0.1673)  loss_classifier: 0.0658 (0.0658)  loss_box_reg: 0.0981 (0.0981)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 0.7015  data: 0.0061  max mem: 6008
# Epoch: [3]  [1000/7516]  eta: 1:41:03  lr: 0.000500  loss: 0.2175 (0.2286)  loss_classifier: 0.0606 (0.0781)  loss_box_reg: 0.1445 (0.1423)  loss_objectness: 0.0010 (0.0027)  loss_rpn_box_reg: 0.0043 (0.0056)  time: 0.9218  data: 0.0056  max mem: 6008
# Epoch: [3]  [2000/7516]  eta: 1:25:23  lr: 0.000500  loss: 0.2267 (0.2242)  loss_classifier: 0.0674 (0.0760)  loss_box_reg: 0.1425 (0.1402)  loss_objectness: 0.0007 (0.0026)  loss_rpn_box_reg: 0.0044 (0.0054)  time: 0.9269  data: 0.0056  max mem: 6008
# Epoch: [3]  [3000/7516]  eta: 1:09:55  lr: 0.000500  loss: 0.2136 (0.2242)  loss_classifier: 0.0624 (0.0758)  loss_box_reg: 0.1452 (0.1403)  loss_objectness: 0.0008 (0.0027)  loss_rpn_box_reg: 0.0052 (0.0054)  time: 0.9430  data: 0.0059  max mem: 6008
# Epoch: [3]  [4000/7516]  eta: 0:54:28  lr: 0.000500  loss: 0.2094 (0.2248)  loss_classifier: 0.0715 (0.0758)  loss_box_reg: 0.1170 (0.1409)  loss_objectness: 0.0007 (0.0026)  loss_rpn_box_reg: 0.0047 (0.0055)  time: 0.9373  data: 0.0055  max mem: 6008
# Epoch: [3]  [5000/7516]  eta: 0:38:56  lr: 0.000500  loss: 0.2059 (0.2237)  loss_classifier: 0.0627 (0.0754)  loss_box_reg: 0.1303 (0.1403)  loss_objectness: 0.0021 (0.0026)  loss_rpn_box_reg: 0.0050 (0.0054)  time: 0.9351  data: 0.0057  max mem: 6008
# Epoch: [3]  [6000/7516]  eta: 0:23:27  lr: 0.000500  loss: 0.2217 (0.2234)  loss_classifier: 0.0684 (0.0752)  loss_box_reg: 0.1368 (0.1403)  loss_objectness: 0.0008 (0.0026)  loss_rpn_box_reg: 0.0045 (0.0054)  time: 0.9126  data: 0.0054  max mem: 6008
# Epoch: [3]  [7000/7516]  eta: 0:07:58  lr: 0.000500  loss: 0.1966 (0.2227)  loss_classifier: 0.0630 (0.0748)  loss_box_reg: 0.1327 (0.1400)  loss_objectness: 0.0012 (0.0026)  loss_rpn_box_reg: 0.0043 (0.0054)  time: 0.9387  data: 0.0057  max mem: 6008
# Epoch: [3]  [7515/7516]  eta: 0:00:00  lr: 0.000500  loss: 0.1925 (0.2226)  loss_classifier: 0.0636 (0.0747)  loss_box_reg: 0.1191 (0.1399)  loss_objectness: 0.0015 (0.0026)  loss_rpn_box_reg: 0.0035 (0.0053)  time: 0.8954  data: 0.0054  max mem: 6008
# Epoch: [3] Total time: 1:56:10 (0.9275 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:13  model_time: 0.1996 (0.1996)  evaluator_time: 0.0077 (0.0077)  time: 0.2317  data: 0.0071  max mem: 6008
# Test:  [100/836]  eta: 0:03:22  model_time: 0.3401 (0.2617)  evaluator_time: 0.0072 (0.0072)  time: 0.3498  data: 0.0052  max mem: 6008
# Test:  [200/836]  eta: 0:03:22  model_time: 0.3466 (0.3047)  evaluator_time: 0.0074 (0.0072)  time: 0.3646  data: 0.0052  max mem: 6008
# Test:  [300/836]  eta: 0:02:59  model_time: 0.3661 (0.3219)  evaluator_time: 0.0069 (0.0072)  time: 0.3795  data: 0.0051  max mem: 6008
# Test:  [400/836]  eta: 0:02:30  model_time: 0.3647 (0.3314)  evaluator_time: 0.0070 (0.0072)  time: 0.3766  data: 0.0057  max mem: 6008
# Test:  [500/836]  eta: 0:01:57  model_time: 0.3464 (0.3374)  evaluator_time: 0.0072 (0.0072)  time: 0.3690  data: 0.0051  max mem: 6008
# Test:  [600/836]  eta: 0:01:23  model_time: 0.3610 (0.3418)  evaluator_time: 0.0069 (0.0072)  time: 0.3745  data: 0.0055  max mem: 6008
# Test:  [700/836]  eta: 0:00:48  model_time: 0.3713 (0.3453)  evaluator_time: 0.0070 (0.0072)  time: 0.3786  data: 0.0057  max mem: 6008
# Test:  [800/836]  eta: 0:00:13  model_time: 0.3564 (0.3481)  evaluator_time: 0.0069 (0.0072)  time: 0.3718  data: 0.0050  max mem: 6008
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3523 (0.3484)  evaluator_time: 0.0068 (0.0072)  time: 0.3583  data: 0.0052  max mem: 6008
# Test: Total time: 0:05:02 (0.3615 s / it)
# Averaged stats: model_time: 0.3523 (0.3484)  evaluator_time: 0.0068 (0.0072)
# Accumulating evaluation results...
# DONE (t=0.61s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.472
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.924
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.418
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.461
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.516
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.567
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.567
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.561
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.592
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.640
# Epoch: [4]  [   0/7516]  eta: 1:29:06  lr: 0.000500  loss: 0.2650 (0.2650)  loss_classifier: 0.0954 (0.0954)  loss_box_reg: 0.1625 (0.1625)  loss_objectness: 0.0026 (0.0026)  loss_rpn_box_reg: 0.0045 (0.0045)  time: 0.7113  data: 0.0072  max mem: 6008
# Epoch: [4]  [1000/7516]  eta: 1:39:32  lr: 0.000500  loss: 0.2131 (0.2209)  loss_classifier: 0.0680 (0.0724)  loss_box_reg: 0.1341 (0.1404)  loss_objectness: 0.0009 (0.0027)  loss_rpn_box_reg: 0.0045 (0.0054)  time: 0.9162  data: 0.0059  max mem: 6008
# Epoch: [4]  [2000/7516]  eta: 1:24:38  lr: 0.000500  loss: 0.2387 (0.2197)  loss_classifier: 0.0772 (0.0722)  loss_box_reg: 0.1569 (0.1397)  loss_objectness: 0.0009 (0.0025)  loss_rpn_box_reg: 0.0058 (0.0052)  time: 0.9054  data: 0.0055  max mem: 6008
# Epoch: [4]  [3000/7516]  eta: 1:09:13  lr: 0.000500  loss: 0.2070 (0.2204)  loss_classifier: 0.0688 (0.0731)  loss_box_reg: 0.1237 (0.1395)  loss_objectness: 0.0011 (0.0025)  loss_rpn_box_reg: 0.0055 (0.0053)  time: 0.9078  data: 0.0055  max mem: 6008
# Epoch: [4]  [4000/7516]  eta: 0:53:56  lr: 0.000500  loss: 0.1985 (0.2203)  loss_classifier: 0.0565 (0.0732)  loss_box_reg: 0.1280 (0.1393)  loss_objectness: 0.0011 (0.0025)  loss_rpn_box_reg: 0.0043 (0.0052)  time: 0.9432  data: 0.0057  max mem: 6008
# Epoch: [4]  [5000/7516]  eta: 0:38:35  lr: 0.000500  loss: 0.2330 (0.2206)  loss_classifier: 0.0755 (0.0733)  loss_box_reg: 0.1384 (0.1395)  loss_objectness: 0.0023 (0.0025)  loss_rpn_box_reg: 0.0044 (0.0053)  time: 0.9328  data: 0.0058  max mem: 6008
# Epoch: [4]  [6000/7516]  eta: 0:23:14  lr: 0.000500  loss: 0.2054 (0.2201)  loss_classifier: 0.0634 (0.0733)  loss_box_reg: 0.1408 (0.1392)  loss_objectness: 0.0008 (0.0025)  loss_rpn_box_reg: 0.0049 (0.0053)  time: 0.9185  data: 0.0059  max mem: 6008
# Epoch: [4]  [7000/7516]  eta: 0:07:54  lr: 0.000500  loss: 0.1723 (0.2200)  loss_classifier: 0.0592 (0.0732)  loss_box_reg: 0.1099 (0.1390)  loss_objectness: 0.0012 (0.0025)  loss_rpn_box_reg: 0.0040 (0.0053)  time: 0.9355  data: 0.0057  max mem: 6008
# Epoch: [4]  [7515/7516]  eta: 0:00:00  lr: 0.000500  loss: 0.1939 (0.2200)  loss_classifier: 0.0717 (0.0732)  loss_box_reg: 0.1226 (0.1390)  loss_objectness: 0.0015 (0.0025)  loss_rpn_box_reg: 0.0039 (0.0053)  time: 0.8687  data: 0.0058  max mem: 6008
# Epoch: [4] Total time: 1:55:14 (0.9200 s / it)
# creating index...
# index created!
# Test:  [  0/836]  eta: 0:03:09  model_time: 0.1943 (0.1943)  evaluator_time: 0.0078 (0.0078)  time: 0.2262  data: 0.0071  max mem: 6008
# Test:  [100/836]  eta: 0:03:22  model_time: 0.3367 (0.2617)  evaluator_time: 0.0073 (0.0072)  time: 0.3492  data: 0.0052  max mem: 6008
# Test:  [200/836]  eta: 0:03:21  model_time: 0.3440 (0.3041)  evaluator_time: 0.0072 (0.0072)  time: 0.3630  data: 0.0054  max mem: 6008
# Test:  [300/836]  eta: 0:02:59  model_time: 0.3623 (0.3212)  evaluator_time: 0.0070 (0.0072)  time: 0.3796  data: 0.0053  max mem: 6008
# Test:  [400/836]  eta: 0:02:29  model_time: 0.3560 (0.3304)  evaluator_time: 0.0070 (0.0072)  time: 0.3716  data: 0.0057  max mem: 6008
# Test:  [500/836]  eta: 0:01:57  model_time: 0.3413 (0.3360)  evaluator_time: 0.0071 (0.0072)  time: 0.3676  data: 0.0051  max mem: 6008
# Test:  [600/836]  eta: 0:01:23  model_time: 0.3692 (0.3403)  evaluator_time: 0.0070 (0.0072)  time: 0.3724  data: 0.0055  max mem: 6008
# Test:  [700/836]  eta: 0:00:48  model_time: 0.3722 (0.3438)  evaluator_time: 0.0070 (0.0072)  time: 0.3804  data: 0.0057  max mem: 6008
# Test:  [800/836]  eta: 0:00:12  model_time: 0.3679 (0.3465)  evaluator_time: 0.0069 (0.0072)  time: 0.3727  data: 0.0051  max mem: 6008
# Test:  [835/836]  eta: 0:00:00  model_time: 0.3529 (0.3467)  evaluator_time: 0.0067 (0.0071)  time: 0.3540  data: 0.0051  max mem: 6008
# Test: Total time: 0:05:00 (0.3599 s / it)
# Averaged stats: model_time: 0.3529 (0.3467)  evaluator_time: 0.0067 (0.0071)
# Accumulating evaluation results...
# DONE (t=0.60s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.470
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.921
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.413
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.459
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.513
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.654
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.561
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.662

# %%
torch.save(
    {
        "epoch": 5,
        "model_state_dict": model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        "lr_scheduler": lr_scheduler.state_dict()
    }, "/Main/faster_rcnn1124.pth")

# %% [markdown]
# ### Predicting the testing images with faster_rcnn1124 and using threshold, then save into json file.

# %%
import os
import numpy as np
import torch
import torch.utils.data
from PIL import Image
import pandas as pd
import torchvision
import matplotlib.pyplot as plt
from model_utils import get_detection_model, get_transform
import json

dir_root = os.listdir("/Main/test/")
dir_root.sort(key=lambda x: int(x[:-4]))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = 11
file_name = 'answer1124_with_threshold_change_bbox.json'
checkpoint = torch.load('/Main/faster_rcnn1124.pth')

model = get_detection_model(num_classes)
model = model.to(device)
model.load_state_dict(checkpoint["model_state_dict"])
results = []
model.eval()
threshold = 0.5

for file in dir_root:
    image = Image.open("/Main/test/" + file)
    img = torchvision.transforms.ToTensor()(image)

    with torch.no_grad():
        prediction = model([img.to(device)])
    for pred in prediction:
        for bbox, label, score in zip(pred["boxes"], pred["labels"],
                                      pred["scores"]):
            if score > threshold:
                bbox = list(bbox.cpu().numpy().astype(float))
                # bbox (x0, y0, width, height)
                bboxes = [float(bbox[0]), float(bbox[1]),
                          (float(bbox[2])-float(bbox[0])),
                          (float(bbox[3])-float(bbox[1]))]
                scores = float(score.cpu().numpy())
                labels = int(label.cpu().numpy())
                p = dict(image_id=int(file[:-4]), score=scores,
                         category_id=labels, bbox=bboxes)
                results.append(p)

with open(file_name, 'w') as f:
    json.dump(results, f, indent=4)

# %% [markdown]
# ### Predicting the testing images with faster_rcnn1124 without using threshold, then save into json file.

# %%
import os
import numpy as np
import torch
import torch.utils.data
from PIL import Image
import pandas as pd
import torchvision
import matplotlib.pyplot as plt
from model_utils import get_detection_model, get_transform
import json

dir_root = os.listdir("/Main/test/")
dir_root.sort(key=lambda x: int(x[:-4]))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = 11
file_name = 'answer1124_change_bbox.json'
checkpoint = torch.load('/Main/faster_rcnn1124.pth')

model = get_detection_model(num_classes)
model = model.to(device)
model.load_state_dict(checkpoint["model_state_dict"])
results = []
model.eval()
threshold = 0.5

for file in dir_root:
    image = Image.open("/Main/test/" + file)
    img = torchvision.transforms.ToTensor()(image)

    with torch.no_grad():
        prediction = model([img.to(device)])
    for pred in prediction:
        for bbox, label, score in zip(pred["boxes"], pred["labels"],
                                      pred["scores"]):
                # if score > threshold:
                bbox = list(bbox.cpu().numpy().astype(float))
                # bbox (x0, y0, width, height)
                bboxes = [float(bbox[0]), float(bbox[1]),
                          (float(bbox[2])-float(bbox[0])),
                          (float(bbox[3])-float(bbox[1]))]
                scores = float(score.cpu().numpy())
                labels = int(label.cpu().numpy())
                p = dict(image_id=int(file[:-4]), score=scores,
                         category_id=labels, bbox=bboxes)
                results.append(p)

with open(file_name, 'w') as f:
    json.dump(results, f, indent=4)

# %% [markdown]
# ### Predicting the testing images with faster_rcnn1125_10_epoch and using threshold, then save into json file.

# %%
import os
import numpy as np
import torch
import torch.utils.data
from PIL import Image
import pandas as pd
import torchvision
import matplotlib.pyplot as plt
from model_utils import get_detection_model, get_transform
import json

dir_root = os.listdir("/Main/test/")
dir_root.sort(key=lambda x: int(x[:-4]))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = 11
file_name = 'answer1125_with_threshold_change_bbox.json'
checkpoint = torch.load('/Main/faster_rcnn1125_10_epoch.pth')

model = get_detection_model(num_classes)
model = model.to(device)
model.load_state_dict(checkpoint["model_state_dict"])
results = []
model.eval()
threshold = 0.5

for file in dir_root:
    image = Image.open("/Main/test/" + file)
    img = torchvision.transforms.ToTensor()(image)

    with torch.no_grad():
        prediction = model([img.to(device)])
    for pred in prediction:
        for bbox, label, score in zip(pred["boxes"], pred["labels"],
                                      pred["scores"]):
            if score > threshold:
                bbox = list(bbox.cpu().numpy().astype(float))
                # bbox (x0, y0, width, height)
                bboxes = [float(bbox[0]), float(bbox[1]),
                          (float(bbox[2])-float(bbox[0])),
                          (float(bbox[3])-float(bbox[1]))]
                scores = float(score.cpu().numpy())
                labels = int(label.cpu().numpy())
                p = dict(image_id=int(file[:-4]), score=scores,
                         ategory_id=labels, bbox=bboxes)
                results.append(p)

with open(file_name, 'w') as f:
    json.dump(results, f, indent=4)

# %% [markdown]
# ### Predicting the testing images with faster_rcnn1125_10_epoch without using threshold, then save into json file.

# %%
import os
import numpy as np
import torch
import torch.utils.data
from PIL import Image
import pandas as pd
import torchvision
import matplotlib.pyplot as plt
from model_utils import get_detection_model, get_transform
import json

dir_root = os.listdir("/Main/test/")
dir_root.sort(key=lambda x: int(x[:-4]))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = 11
file_name = 'answer1125_change_bbox.json'
checkpoint = torch.load('/Main/faster_rcnn1125_10_epoch.pth')

model = get_detection_model(num_classes)
model = model.to(device)
model.load_state_dict(checkpoint["model_state_dict"])
results = []
model.eval()
threshold = 0.5

for file in dir_root:
    image = Image.open("/Main/test/" + file)
    img = torchvision.transforms.ToTensor()(image)

    with torch.no_grad():
        prediction = model([img.to(device)])
    for pred in prediction:
        for bbox, label, score in zip(pred["boxes"], pred["labels"],
                                      pred["scores"]):
                # if score > threshold:
                bbox = list(bbox.cpu().numpy().astype(float))
                # bbox (x0, y0, width, height)
                bboxes = [float(bbox[0]), float(bbox[1]),
                          (float(bbox[2])-float(bbox[0])),
                          (float(bbox[3])-float(bbox[1]))]
                scores = float(score.cpu().numpy())
                labels = int(label.cpu().numpy())
                p = dict(image_id=int(file[:-4]), score=scores,
                         ategory_id=labels, bbox=bboxes)
                results.append(p)

with open(file_name, 'w') as f:
    json.dump(results, f, indent=4)
